# %%
import numpy as np
from ase.io.trajectory import Trajectory
from ase.visualize import view
from glob import glob
sys.path.append('/media/rbnfiles/ruco/repos/atomistic-analysis/src')
from opendata import data

class data:
    def __init__(self):
        self.path  = "/media/rbnfiles/dft/pts2/"
        self.folders = []
        self.files = []
        self.complete_folders= []
        self.complete_files = []
        for folder in glob(self.path+"*"):
            self.folders.append(folder.split('/')[-1])
            self.complete_folders.append(folder)
        for folder in  self.complete_folders:
            for filesinto in glob(folder+'/*.traj'):
                self.complete_files.append(filesinto)

    def get_list_samples(self,folder):
        npath = self.path+'/'+folder
        self.folder_samples=[]
        for folderi in self.complete_folders:
            if folder in folderi:
                for (path,dir,files) in os.walk(folder):
                    for filesinto in glob(path+'/*.traj'):
                    #self.folder_samples.append(filesinto.split(self.path)[-1].split('/')[-1])
                        self.folder_samples.append(filesinto)

        return self.folder_samples


    def return_data(self,file):
        for files in self.complete_files:
            if file in files:
                self.select_file = file
                break
        return self.select_file
cf = data().complete_folders
cf
# Out:
# ['/media/rbnfiles/dft/pts2/2x2supercellPtS2',
#  '/media/rbnfiles/dft/pts2/3x3supercellPtS2',
#  '/media/rbnfiles/dft/pts2/teststruct']

# %%
for (path,dir,files) in os.walk(cf[0]):
     for filesinto in glob(path+'/*.traj'):
         print(filesinto)
# Out:
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/PtSe2_2x2SupvacancyPt.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_-0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_-0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_-0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_PtSe2_VacPt.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/VacPt_Opt_PtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_-0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/uCellPtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_PtS2_VacPt_PW.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/PtS2_2x2SupvacancyPt.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_-0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_PtS2_VacPt.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/PtS2_VacPt_magn.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/Opt_VacPt_PtS2_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/VacPt_Opt_PtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/Opt_PtS2_VacPt_PW.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.035.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_-0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.025.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.055.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.045.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_-0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/optStruct/VacPt_PtS2_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_-0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_-0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.045.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.055.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.035.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.025.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso2/mangetic/PtS2_vacPt_magnetic_0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/VacPt_Opt_PtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/Opt_PtS2_VacPt_PW.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.035.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.035.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.025.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.045.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.065.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.055.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.055.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.045.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.065.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.025.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_-0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/optStruct/VacPt_PtS2_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.065.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.055.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.015.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.045.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.055.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.035.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.005.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.045.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.065.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.025.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.035.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.025.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_-0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/iso/mangetic/PtS2_vacPt_magnetic_0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Ansio2/VacPt_Opt_PtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Ansio2/Opt_VacPt_PtS2_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/VacPt_Opt_PtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/Opt_VacPt_PtS2_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_-0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/optStruct/VacPt_PtS2_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.07.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.04.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.06.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.02.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.03.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.01.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_0.0.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/strain/Aniso/magnetic/PtS2_vacPt_magnetic_-0.05.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/band2x2/noSOC/VacPt_Opt_PtS2.traj
# /media/rbnfiles/dft/pts2/2x2supercellPtS2/band2x2/SOC/VacPt_Opt_PtS2.traj
