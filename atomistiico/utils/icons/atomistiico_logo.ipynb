# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt


files = !ls *.png
atiico_icon = Image.open(files[-1])
x1, y1 = 204, 153 #
x2, y2 = 475, 520 # 
cutregion = (x1, y1, x2, y2)
image_crop = atiico_icon.crop(cutregion)
atiico_icon = image_crop

# puppy_icon.putalpha(230)
d = ImageDraw.Draw(atiico_icon)
font = ImageFont.truetype("fonts/Wigglye.ttf", size=100)
font2 = ImageFont.truetype("fonts/Wigglye.ttf", size=70)
font3 = ImageFont.truetype("fonts/Wigglye.ttf", size=50)

# d.text((170,100), "SEDA",font=font)
# d.text((230,200), "by",font=font2)
# d.text((170,250), "Puppy",font=font)
d.text((30,150), "AtomistIICO",font=font3,fill='Purple')
atiico_icon.save('atiico_icon.png')

plt.figure(figsize=(10,10))
plt.imshow(atiico_icon)
plt.show()

# %%
atiico_icon
# Out:
# <PIL.Image.Image image mode=RGBA size=271x367>

# %%
files = !ls *.png
files
# Out:
# ['a1.png', 'atiico_icon.png', 'PtS2.png']
